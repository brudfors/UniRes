# %% [markdown]
# ## Reconstruct multi-channel BrainWeb simulations and compute NMI
#
# This notebook applies the forward model of UniRes to 'ideal' MR images from the BrainWeb simulator [1], generating degraded, low-resolution (LR) images as x[i] = A[i]y[i] + n, i={0, 1, 2}. The LR images are then reconstructed using the UniRes super-resolution algorithm. The normalized mutual information (NMI) is computed between the reconstructions.
#
# 1. https://brainweb.bic.mni.mcgill.ca/
#
# ### Requirements
# ```sh
# pip install scikit-image
# ```

# %%
from nitorch.plot import show_slices
from nitorch import io
from nitorch.spatial import affine_matrix_classic
from numpy.random import random_sample as rnd
import torch
from unires._project import (_proj_apply, _proj_info)
from unires.struct import settings
from unires.run import preproc
from skimage.metrics import structural_similarity as ssim
from skimage.metrics import normalized_mutual_information as nmi

# %%
# Load images
pths = [
    "../data/t1_icbm_normal_1mm_pn0_rf0.nii.gz",
    "../data/t2_icbm_normal_1mm_pn0_rf0.nii.gz",
    "../data/pd_icbm_normal_1mm_pn0_rf0.nii.gz",
]
nii_y, y = [], []
for pth in pths:  nii_y.append(io.map(pth))
for nii in nii_y:  y.append(nii.fdata())

# Visualise
figsize = (7/1.5, 3/1.5)
_ = [show_slices(y[i], figsize=figsize, fig_num=i) for i in range(len(y))]

# %%
# Apply UniRes forward model to BrainWeb MRIs (y[i] = A[i]x[i] + n)

# Parameters
# https://github.com/brudfors/UniRes/blob/master/unires/struct.py#L57
vx_ts = 4  # thick-slice voxel size
prof_ip = 0  # (0=rect|1=tri|2=gauss)
prof_tp = 0  # (0=rect|1=tri|2=gauss)
s_gap = 0.0  # slice gap
device = "cuda"  # GPU or CPU
eo_scl = 0.1  # even/odd slice scaling
std_noise = 75  # std of Gaussian noise
rigid_t = 10.0  # amount of random translation
rigid_r = 0.2  # amount of random rotation

x, mat_x, dim_y = [], [], []
for i in range(len(y)):

    # Set output field of view
    vx_scl = torch.ones(3)
    vx_scl[i] = vx_ts
    mat_y = nii_y[i].affine
    dim_y.append(torch.as_tensor(y[i].shape, dtype=mat_y.dtype))
    scl = torch.as_tensor(torch.cat((vx_scl, torch.ones(1))), dtype=mat_y.dtype)
    mat_scl = torch.diag(scl)
    mat_x.append(mat_y.mm(mat_scl))
    dim_x = mat_scl[:3, :3].inverse().mm(dim_y[i][:, None]).floor().squeeze()
    print(f"dim_y[{i}]={dim_y[i]}")
    print(f"dim_x[{i}]={dim_x}")

    # Set device
    mat_x[i] = mat_x[i].to(device)
    mat_y = mat_y.to(device)
    dim_y[i] = dim_y[i].to(device)
    dim_x = dim_x.to(device)
    y[i] = y[i].to(device)

    # Random rigid matrix
    rigid = affine_matrix_classic(
        [
            rigid_t*rnd() - rigid_t/2, rigid_t*rnd() - rigid_t/2, rigid_t*rnd() - rigid_t/2, 
            rigid_r*rnd() - rigid_r/2, rigid_r*rnd() - rigid_r/2, rigid_r*rnd() - rigid_r/2,
        ],
    ).to(device)

    # Create projection operator
    po = _proj_info(
        dim_y[i], mat_y, dim_x, mat_x[i], 
        rigid=rigid, prof_ip=prof_ip, prof_tp=prof_tp, 
        gap=s_gap, device=device, scl=eo_scl
    )
    A = lambda y: _proj_apply("A", y[None, None, ...], po)[0, 0, ...]
    n = std_noise*torch.randn(dim_x.cpu().type(torch.int).tolist(), device=device)

    # Apply forward model A
    x.append(A(y[i]) + n)

# Visualise
_ = [show_slices(x[i], figsize=figsize, fig_num=i) for i in range(len(x))]
# Out:
# dim_y[0]=tensor([181., 217., 181.], dtype=torch.float64)
# dim_x[0]=tensor([ 45., 217., 181.], dtype=torch.float64)
# dim_y[1]=tensor([181., 217., 181.], dtype=torch.float64)
# dim_x[1]=tensor([181.,  54., 181.], dtype=torch.float64)
# dim_y[2]=tensor([181., 217., 181.], dtype=torch.float64)
# dim_x[2]=tensor([181., 217.,  45.], dtype=torch.float64)

# %%
# Run UniRes with unified super-resolution

# Set input data
data = []
for i in range(len(x)):
    data.append([[x[i], mat_x[i]]])

# Settings
s = settings()
s.write_out = False
s.pow = dim_y[i].cpu().type(torch.int).tolist()
# Run algorithm
y_hat, _, _ = preproc(data, sett=s)
# Out:
#   _   _       _ ____
#  | | | |_ __ (_)  _ \ ___  ___
#  | | | | '_ \| | |_) / _ \/ __|
#  | |_| | | | | |  _ <  __/\__ \
#   \___/|_| |_|_|_| \_\___||___/
#
# 28/04/2023 11:53:12 | GPU: NVIDIA RTX A6000, CUDA: True, PyTorch: 2.0.0
#
# Input
# c=0, n=0 | fname=None
# c=1, n=0 | fname=None
# c=2, n=0 | fname=None
#
# Estimating model hyper-parameters... completed in 0.21517 seconds:
# c=0 | tau= 0.0001571 | sd=     79.77 | mu=     448.8 | ct=False
# c=1 | tau= 0.0001538 | sd=     80.64 | mu=      1954 | ct=False
# c=2 | tau= 9.519e-05 | sd=     102.5 | mu=      4395 | ct=False
#
# Performing multi-channel (N=3) alignment...completed in 3.43716 seconds.
#
# Mean space | dim=(181, 217, 181), vx=(1.0, 1.0, 1.0)
#
# ADMM step-size=0.6367
#
# Starting super-resolution (update_rigid=True, update_scaling=True)
#  | C=3 | N=3 | device=cuda | max_iter=512 | tol=0.0001 | sched_num=3
#   0 - Convergence ( 1.4 s)  | nlyx =  5.135e+07, nlxy =  3.401e+07, nly =  1.733e+07, gain =        inf
#   1 - Convergence ( 1.5 s)  | nlyx =  4.392e+07, nlxy =  2.721e+07, nly =  1.671e+07, gain =  1.0000000
#   2 - Convergence ( 2.1 s)  | nlyx =  4.031e+07, nlxy =  2.204e+07, nly =  1.827e+07, gain =  0.3276695
#   3 - Convergence ( 1.9 s)  | nlyx =  3.897e+07, nlxy =  2.008e+07, nly =  1.889e+07, gain =  0.1079103
#   4 - Convergence ( 2.1 s)  | nlyx =  3.818e+07, nlxy =  1.898e+07, nly =   1.92e+07, gain =  0.0600767
#   5 - Convergence ( 1.7 s)  | nlyx =  3.766e+07, nlxy =  1.828e+07, nly =  1.938e+07, gain =  0.0379891
#   6 - Convergence ( 1.5 s)  | nlyx =  3.729e+07, nlxy =   1.78e+07, nly =  1.949e+07, gain =  0.0265830
#   7 - Convergence ( 2.1 s)  | nlyx =  3.701e+07, nlxy =  1.743e+07, nly =  1.958e+07, gain =  0.0190451
#   8 - Convergence ( 1.9 s)  | nlyx =  3.681e+07, nlxy =  1.715e+07, nly =  1.967e+07, gain =  0.0136083
#   9 - Convergence ( 1.7 s)  | nlyx =  3.665e+07, nlxy =  1.693e+07, nly =  1.972e+07, gain =  0.0109853
#  10 - Convergence ( 1.9 s)  | nlyx =  3.652e+07, nlxy =  1.675e+07, nly =  1.978e+07, gain =  0.0088207
#  11 - Convergence ( 1.8 s)  | nlyx =  3.642e+07, nlxy =   1.66e+07, nly =  1.982e+07, gain =  0.0067820
#  12 - Convergence ( 1.8 s)  | nlyx =  3.634e+07, nlxy =  1.648e+07, nly =  1.986e+07, gain =  0.0056454
#  13 - Convergence ( 2.1 s)  | nlyx =  3.627e+07, nlxy =  1.637e+07, nly =  1.989e+07, gain =  0.0046748
#  14 - Convergence ( 1.8 s)  | nlyx =  3.621e+07, nlxy =  1.629e+07, nly =  1.992e+07, gain =  0.0039210
#  15 - Convergence ( 1.6 s)  | nlyx =  3.616e+07, nlxy =  1.621e+07, nly =  1.994e+07, gain =  0.0033786
#  16 - Convergence ( 1.9 s)  | nlyx =  3.611e+07, nlxy =  1.615e+07, nly =  1.996e+07, gain =  0.0029113
#  17 - Convergence ( 2.0 s)  | nlyx =  3.607e+07, nlxy =  1.609e+07, nly =  1.998e+07, gain =  0.0024659
#  18 - Convergence ( 1.7 s)  | nlyx =  3.604e+07, nlxy =  1.604e+07, nly =      2e+07, gain =  0.0021707
#  19 - Convergence ( 1.6 s)  | nlyx =  3.601e+07, nlxy =    1.6e+07, nly =  2.001e+07, gain =  0.0019384
#  20 - Convergence ( 1.9 s)  | nlyx =  3.598e+07, nlxy =  1.596e+07, nly =  2.003e+07, gain =  0.0016951
#  21 - Convergence ( 1.8 s)  | nlyx =  3.596e+07, nlxy =  1.592e+07, nly =  2.004e+07, gain =  0.0015219
#  22 - Convergence ( 1.6 s)  | nlyx =  3.594e+07, nlxy =  1.589e+07, nly =  2.005e+07, gain =  0.0015157
#  23 - Convergence ( 1.7 s)  | nlyx =  3.592e+07, nlxy =  1.586e+07, nly =  2.005e+07, gain =  0.0012545
#  24 - Convergence ( 1.6 s)  | nlyx =   3.59e+07, nlxy =  1.584e+07, nly =  2.006e+07, gain =  0.0011569
#  25 - Convergence ( 1.6 s)  | nlyx =  3.588e+07, nlxy =  1.581e+07, nly =  2.007e+07, gain =  0.0011464
#  26 - Convergence ( 1.5 s)  | nlyx =  3.587e+07, nlxy =  1.579e+07, nly =  2.007e+07, gain =  0.0009368
#  27 - Convergence ( 1.6 s)  | nlyx =  3.585e+07, nlxy =  1.577e+07, nly =  2.008e+07, gain =  0.0009388
#  28 - Convergence ( 1.6 s)  | nlyx =  3.584e+07, nlxy =  1.575e+07, nly =  2.009e+07, gain =  0.0008969
#  29 - Convergence ( 1.9 s)  | nlyx =  3.583e+07, nlxy =  1.574e+07, nly =  2.009e+07, gain =  0.0008311
#  30 - Convergence ( 2.1 s)  | nlyx =  3.581e+07, nlxy =  1.572e+07, nly =  2.009e+07, gain =  0.0008311
#  31 - Convergence ( 1.8 s)  | nlyx =   3.58e+07, nlxy =  1.571e+07, nly =   2.01e+07, gain =  0.0007400
# OBS: Regularisation changed from 4.20E-03 to 2.10E-03
#  32 - Convergence ( 2.0 s)  | nlyx =  3.053e+07, nlxy =  1.433e+07, nly =   1.62e+07, gain =  0.2531776
#  33 - Convergence ( 2.0 s)  | nlyx =   2.65e+07, nlxy =  1.255e+07, nly =  1.395e+07, gain =  0.1624049
#  34 - Convergence ( 2.1 s)  | nlyx =  2.556e+07, nlxy =  1.247e+07, nly =  1.309e+07, gain =  0.0363787
#  35 - Convergence ( 2.0 s)  | nlyx =   2.52e+07, nlxy =  1.254e+07, nly =  1.266e+07, gain =  0.0137700
#  36 - Convergence ( 2.0 s)  | nlyx =  2.503e+07, nlxy =  1.261e+07, nly =  1.241e+07, gain =  0.0066255
#  37 - Convergence ( 1.9 s)  | nlyx =  2.493e+07, nlxy =  1.266e+07, nly =  1.227e+07, gain =  0.0037718
#  38 - Convergence ( 2.3 s)  | nlyx =  2.487e+07, nlxy =  1.268e+07, nly =  1.219e+07, gain =  0.0022400
#  39 - Convergence ( 2.1 s)  | nlyx =  2.482e+07, nlxy =  1.269e+07, nly =  1.213e+07, gain =  0.0015793
#  40 - Convergence ( 1.9 s)  | nlyx =   2.48e+07, nlxy =   1.27e+07, nly =  1.209e+07, gain =  0.0010854
#  41 - Convergence ( 2.0 s)  | nlyx =  2.477e+07, nlxy =   1.27e+07, nly =  1.207e+07, gain =  0.0008990
#  42 - Convergence ( 1.7 s)  | nlyx =  2.476e+07, nlxy =  1.271e+07, nly =  1.205e+07, gain =  0.0006414
#  43 - Convergence ( 1.5 s)  | nlyx =  2.474e+07, nlxy =   1.27e+07, nly =  1.204e+07, gain =  0.0005733
#  44 - Convergence ( 1.4 s)  | nlyx =  2.473e+07, nlxy =   1.27e+07, nly =  1.203e+07, gain =  0.0004391
#  45 - Convergence ( 1.4 s)  | nlyx =  2.472e+07, nlxy =   1.27e+07, nly =  1.202e+07, gain =  0.0003439
#  46 - Convergence ( 2.0 s)  | nlyx =  2.471e+07, nlxy =   1.27e+07, nly =  1.201e+07, gain =  0.0002644
#  47 - Convergence ( 1.8 s)  | nlyx =  2.471e+07, nlxy =   1.27e+07, nly =  1.201e+07, gain =  0.0001827
#  48 - Convergence ( 1.6 s)  | nlyx =   2.47e+07, nlxy =   1.27e+07, nly =  1.201e+07, gain =  0.0001454
#  49 - Convergence ( 2.1 s)  | nlyx =   2.47e+07, nlxy =  1.269e+07, nly =    1.2e+07, gain =  0.0001264
#  50 - Convergence ( 2.0 s)  | nlyx =   2.47e+07, nlxy =  1.269e+07, nly =    1.2e+07, gain =  0.0000996
#  51 - Convergence ( 1.6 s)  | nlyx =  2.469e+07, nlxy =  1.269e+07, nly =    1.2e+07, gain =  0.0000879
#  52 - Convergence ( 1.7 s)  | nlyx =  2.469e+07, nlxy =  1.269e+07, nly =    1.2e+07, gain =  0.0000764
#  53 - Convergence ( 1.6 s)  | nlyx =  2.469e+07, nlxy =  1.269e+07, nly =    1.2e+07, gain =  0.0000651
# OBS: Regularisation changed from 2.10E-03 to 1.05E-03
#  54 - Convergence ( 1.9 s)  | nlyx =   2.27e+07, nlxy =  1.329e+07, nly =  9.411e+06, gain =  0.0693732
#  55 - Convergence ( 1.9 s)  | nlyx =  1.971e+07, nlxy =  1.159e+07, nly =   8.12e+06, gain =  0.0946137
#  56 - Convergence ( 1.9 s)  | nlyx =  1.899e+07, nlxy =  1.135e+07, nly =  7.639e+06, gain =  0.0223531
#  57 - Convergence ( 1.9 s)  | nlyx =  1.869e+07, nlxy =   1.13e+07, nly =  7.383e+06, gain =  0.0091879
#  58 - Convergence ( 1.8 s)  | nlyx =  1.853e+07, nlxy =   1.13e+07, nly =  7.234e+06, gain =  0.0046794
#  59 - Convergence ( 1.8 s)  | nlyx =  1.845e+07, nlxy =   1.13e+07, nly =  7.143e+06, gain =  0.0026706
#  60 - Convergence ( 1.7 s)  | nlyx =  1.839e+07, nlxy =  1.131e+07, nly =  7.084e+06, gain =  0.0016355
#  61 - Convergence ( 1.7 s)  | nlyx =  1.836e+07, nlxy =  1.131e+07, nly =  7.045e+06, gain =  0.0010643
#  62 - Convergence ( 1.7 s)  | nlyx =  1.833e+07, nlxy =  1.131e+07, nly =  7.018e+06, gain =  0.0007576
#  63 - Convergence ( 1.5 s)  | nlyx =  1.831e+07, nlxy =  1.131e+07, nly =  6.998e+06, gain =  0.0005710
#  64 - Convergence ( 1.5 s)  | nlyx =   1.83e+07, nlxy =  1.132e+07, nly =  6.983e+06, gain =  0.0004485
#  65 - Convergence ( 1.6 s)  | nlyx =  1.829e+07, nlxy =  1.131e+07, nly =  6.972e+06, gain =  0.0003633
#  66 - Convergence ( 1.4 s)  | nlyx =  1.828e+07, nlxy =  1.131e+07, nly =  6.963e+06, gain =  0.0003028
#  67 - Convergence ( 1.4 s)  | nlyx =  1.827e+07, nlxy =  1.131e+07, nly =  6.956e+06, gain =  0.0002629
#  68 - Convergence ( 1.4 s)  | nlyx =  1.826e+07, nlxy =  1.131e+07, nly =  6.951e+06, gain =  0.0002314
#  69 - Convergence ( 1.4 s)  | nlyx =  1.825e+07, nlxy =  1.131e+07, nly =  6.946e+06, gain =  0.0001979
#  70 - Convergence ( 1.5 s)  | nlyx =  1.825e+07, nlxy =  1.131e+07, nly =  6.942e+06, gain =  0.0001875
#  71 - Convergence ( 1.6 s)  | nlyx =  1.824e+07, nlxy =   1.13e+07, nly =  6.939e+06, gain =  0.0001414
#  72 - Convergence ( 1.4 s)  | nlyx =  1.824e+07, nlxy =   1.13e+07, nly =  6.936e+06, gain =  0.0001548
#  73 - Convergence ( 1.5 s)  | nlyx =  1.823e+07, nlxy =   1.13e+07, nly =  6.934e+06, gain =  0.0001257
#  74 - Convergence ( 1.6 s)  | nlyx =  1.823e+07, nlxy =   1.13e+07, nly =  6.932e+06, gain =  0.0001283
#  75 - Convergence ( 1.4 s)  | nlyx =  1.823e+07, nlxy =   1.13e+07, nly =   6.93e+06, gain =  0.0001056
# OBS: Regularisation changed from 1.05E-03 to 5.25E-04
#  76 - Convergence ( 1.7 s)  | nlyx =  1.732e+07, nlxy =  1.201e+07, nly =  5.309e+06, gain =  0.0265969
#  77 - Convergence ( 1.8 s)  | nlyx =  1.538e+07, nlxy =  1.071e+07, nly =  4.662e+06, gain =  0.0540498
#  78 - Convergence ( 1.8 s)  | nlyx =  1.496e+07, nlxy =  1.053e+07, nly =  4.424e+06, gain =  0.0115621
#  79 - Convergence ( 1.8 s)  | nlyx =  1.479e+07, nlxy =   1.05e+07, nly =  4.293e+06, gain =  0.0045050
#  80 - Convergence ( 1.7 s)  | nlyx =  1.471e+07, nlxy =  1.049e+07, nly =  4.213e+06, gain =  0.0022821
#  81 - Convergence ( 1.7 s)  | nlyx =  1.466e+07, nlxy =   1.05e+07, nly =  4.161e+06, gain =  0.0013791
#  82 - Convergence ( 1.6 s)  | nlyx =  1.462e+07, nlxy =   1.05e+07, nly =  4.126e+06, gain =  0.0009155
#  83 - Convergence ( 1.6 s)  | nlyx =   1.46e+07, nlxy =   1.05e+07, nly =  4.102e+06, gain =  0.0006918
#  84 - Convergence ( 1.5 s)  | nlyx =  1.458e+07, nlxy =   1.05e+07, nly =  4.084e+06, gain =  0.0005139
#  85 - Convergence ( 1.6 s)  | nlyx =  1.456e+07, nlxy =  1.049e+07, nly =   4.07e+06, gain =  0.0004302
#  86 - Convergence ( 1.5 s)  | nlyx =  1.455e+07, nlxy =  1.049e+07, nly =  4.059e+06, gain =  0.0003503
#  87 - Convergence ( 1.4 s)  | nlyx =  1.454e+07, nlxy =  1.049e+07, nly =  4.051e+06, gain =  0.0002934
#  88 - Convergence ( 1.5 s)  | nlyx =  1.453e+07, nlxy =  1.049e+07, nly =  4.044e+06, gain =  0.0002831
#  89 - Convergence ( 1.4 s)  | nlyx =  1.452e+07, nlxy =  1.048e+07, nly =  4.038e+06, gain =  0.0002329
#  90 - Convergence ( 1.4 s)  | nlyx =  1.451e+07, nlxy =  1.048e+07, nly =  4.033e+06, gain =  0.0002065
#  91 - Convergence ( 1.7 s)  | nlyx =  1.451e+07, nlxy =  1.048e+07, nly =  4.029e+06, gain =  0.0001893
#  92 - Convergence ( 2.0 s)  | nlyx =   1.45e+07, nlxy =  1.047e+07, nly =  4.025e+06, gain =  0.0001920
#  93 - Convergence ( 1.5 s)  | nlyx =  1.449e+07, nlxy =  1.047e+07, nly =  4.022e+06, gain =  0.0001624
#  94 - Convergence ( 1.5 s)  | nlyx =  1.449e+07, nlxy =  1.047e+07, nly =  4.019e+06, gain =  0.0001653
#  95 - Convergence ( 1.5 s)  | nlyx =  1.448e+07, nlxy =  1.046e+07, nly =  4.017e+06, gain =  0.0001419
#  96 - Convergence ( 1.5 s)  | nlyx =  1.448e+07, nlxy =  1.046e+07, nly =  4.015e+06, gain =  0.0001490
#  97 - Convergence ( 1.4 s)  | nlyx =  1.447e+07, nlxy =  1.046e+07, nly =  4.013e+06, gain =  0.0001257
#  98 - Convergence ( 1.4 s)  | nlyx =  1.447e+07, nlxy =  1.046e+07, nly =  4.011e+06, gain =  0.0001260
#  99 - Convergence ( 1.4 s)  | nlyx =  1.446e+07, nlxy =  1.045e+07, nly =  4.009e+06, gain =  0.0001152
# 100 - Convergence ( 1.5 s)  | nlyx =  1.446e+07, nlxy =  1.045e+07, nly =  4.008e+06, gain =  0.0001225
# 101 - Convergence ( 2.0 s)  | nlyx =  1.445e+07, nlxy =  1.045e+07, nly =  4.007e+06, gain =  0.0001128
# 102 - Convergence ( 1.6 s)  | nlyx =  1.445e+07, nlxy =  1.044e+07, nly =  4.005e+06, gain =  0.0001094
# 103 - Convergence ( 1.5 s)  | nlyx =  1.445e+07, nlxy =  1.044e+07, nly =  4.004e+06, gain =  0.0001216
# 104 - Convergence ( 1.4 s)  | nlyx =  1.444e+07, nlxy =  1.044e+07, nly =  4.003e+06, gain =  0.0000976
# 105 - Convergence ( 1.4 s)  | nlyx =  1.444e+07, nlxy =  1.044e+07, nly =  4.002e+06, gain =  0.0001050
# 106 - Convergence ( 1.5 s)  | nlyx =  1.443e+07, nlxy =  1.043e+07, nly =  4.001e+06, gain =  0.0000894
# 107 - Convergence ( 2.0 s)  | nlyx =  1.443e+07, nlxy =  1.043e+07, nly =      4e+06, gain =  0.0000920
# 108 - Convergence ( 1.6 s)  | nlyx =  1.443e+07, nlxy =  1.043e+07, nly =  3.999e+06, gain =  0.0000775
# 109 - Convergence ( 1.4 s)  | nlyx =  1.442e+07, nlxy =  1.043e+07, nly =  3.998e+06, gain =  0.0001010
# 110 - Convergence ( 1.4 s)  | nlyx =  1.442e+07, nlxy =  1.042e+07, nly =  3.998e+06, gain =  0.0000793
# 111 - Convergence ( 1.5 s)  | nlyx =  1.442e+07, nlxy =  1.042e+07, nly =  3.997e+06, gain =  0.0000965
# 112 - Convergence ( 2.0 s)  | nlyx =  1.441e+07, nlxy =  1.042e+07, nly =  3.996e+06, gain =  0.0000849
# 113 - Convergence ( 1.6 s)  | nlyx =  1.441e+07, nlxy =  1.042e+07, nly =  3.996e+06, gain =  0.0001124
# 114 - Convergence ( 1.5 s)  | nlyx =  1.441e+07, nlxy =  1.041e+07, nly =  3.995e+06, gain =  0.0000888
# 115 - Convergence ( 1.5 s)  | nlyx =   1.44e+07, nlxy =  1.041e+07, nly =  3.994e+06, gain =  0.0000875
# 116 - Convergence ( 2.0 s)  | nlyx =   1.44e+07, nlxy =  1.041e+07, nly =  3.994e+06, gain =  0.0000797
# 117 - Convergence ( 1.6 s)  | nlyx =   1.44e+07, nlxy =  1.041e+07, nly =  3.993e+06, gain =  0.0000615
# 118 - Convergence ( 1.5 s)  | nlyx =   1.44e+07, nlxy =   1.04e+07, nly =  3.993e+06, gain =  0.0000831
# 119 - Convergence ( 2.0 s)  | nlyx =  1.439e+07, nlxy =   1.04e+07, nly =  3.992e+06, gain =  0.0000786
#  super-resolution finished in 203.58561 seconds and 120 iterations
#
# UniRes-output

# %%
# Visualise results
_ = [show_slices(y_hat[..., i], figsize=figsize, fig_num=i) for i in range(len(x))]

# %%
# Compute NMI
i0, i1 = 0, 1
nmi_sr = nmi(y_hat[..., i0].cpu().numpy(), y_hat[..., i1].cpu().numpy()) - 1
print(f"NMI(y[{i0}], y_hat[{i1}])={nmi_sr}")
i0, i1 = 0, 2
nmi_sr = nmi(y_hat[..., i0].cpu().numpy(), y_hat[..., i1].cpu().numpy()) - 1
print(f"NMI(y[{i0}], y_hat[{i1}])={nmi_sr}")
i0, i1 = 1, 2
nmi_sr = nmi(y_hat[..., i0].cpu().numpy(), y_hat[..., i1].cpu().numpy()) - 1
print(f"NMI(y[{i0}], y_hat[{i1}])={nmi_sr}")
# Out:
# NMI(y[0], y_hat[1])=0.20385733034538345
# NMI(y[0], y_hat[2])=0.19270995232351695
# NMI(y[1], y_hat[2])=0.1864518115182019
